# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('darkgrid')

import warnings
warnings.filterwarnings('ignore')

# %%
exam = pd.read_csv('energydata_complete.csv')

exam
# Out:
#                       date  Appliances  lights         T1       RH_1  \
# 0      2016-01-11 17:00:00          60      30  19.890000  47.596667
# 1      2016-01-11 17:10:00          60      30  19.890000  46.693333
# 2      2016-01-11 17:20:00          50      30  19.890000  46.300000
# 3      2016-01-11 17:30:00          50      40  19.890000  46.066667
# 4      2016-01-11 17:40:00          60      40  19.890000  46.333333
# ...                    ...         ...     ...        ...        ...
# 19730  2016-05-27 17:20:00         100       0  25.566667  46.560000
# 19731  2016-05-27 17:30:00          90       0  25.500000  46.500000
# 19732  2016-05-27 17:40:00         270      10  25.500000  46.596667
# 19733  2016-05-27 17:50:00         420      10  25.500000  46.990000
# 19734  2016-05-27 18:00:00         430      10  25.500000  46.600000
#
#               T2       RH_2         T3       RH_3         T4  ...         T9  \
# ...

# %%
exam.head(5)
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
exam
# Out:
#                       date  Appliances  lights         T1       RH_1  \
# 0      2016-01-11 17:00:00          60      30  19.890000  47.596667
# 1      2016-01-11 17:10:00          60      30  19.890000  46.693333
# 2      2016-01-11 17:20:00          50      30  19.890000  46.300000
# 3      2016-01-11 17:30:00          50      40  19.890000  46.066667
# 4      2016-01-11 17:40:00          60      40  19.890000  46.333333
# ...                    ...         ...     ...        ...        ...
# 19730  2016-05-27 17:20:00         100       0  25.566667  46.560000
# 19731  2016-05-27 17:30:00          90       0  25.500000  46.500000
# 19732  2016-05-27 17:40:00         270      10  25.500000  46.596667
# 19733  2016-05-27 17:50:00         420      10  25.500000  46.990000
# 19734  2016-05-27 18:00:00         430      10  25.500000  46.600000
#
#               T2       RH_2         T3       RH_3         T4  ...         T9  \
# ...

# %%
exam.describe().T
# Out:
#                count        mean         std         min         25%  \
# Appliances   19735.0   97.694958  102.524891   10.000000   50.000000
# lights       19735.0    3.801875    7.935988    0.000000    0.000000
# T1           19735.0   21.686571    1.606066   16.790000   20.760000
# RH_1         19735.0   40.259739    3.979299   27.023333   37.333333
# T2           19735.0   20.341219    2.192974   16.100000   18.790000
# RH_2         19735.0   40.420420    4.069813   20.463333   37.900000
# T3           19735.0   22.267611    2.006111   17.200000   20.790000
# RH_3         19735.0   39.242500    3.254576   28.766667   36.900000
# T4           19735.0   20.855335    2.042884   15.100000   19.530000
# RH_4         19735.0   39.026904    4.341321   27.660000   35.530000
# T5           19735.0   19.592106    1.844623   15.330000   18.277500
# RH_5         19735.0   50.949283    9.022034   29.815000   45.400000
# T6           19735.0    7.910939    6.090347   -6.065000    3.626667
# ...

# %%
exam.columns
# Out:
# Index(['date', 'Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3',
#        'RH_3', 'T4', 'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8',
#        'RH_8', 'T9', 'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed',
#        'Visibility', 'Tdewpoint', 'rv1', 'rv2'],
#       dtype='object')

# %%
exam.value_counts()
# Out:
# date                 Appliances  lights  T1     RH_1       T2         RH_2       T3         RH_3       T4         RH_4       T5         RH_5       T6         RH_6       T7         RH_7       T8      RH_8       T9         RH_9       T_out      Press_mm_hg  RH_out     Windspeed  Visibility  Tdewpoint  rv1        rv2
# 2016-01-11 17:00:00  60          30      19.89  47.596667  19.200000  44.790000  19.790000  44.730000  19.000000  45.566667  17.166667  55.200000  7.026667   84.256667  17.200000  41.626667  18.200  48.900000  17.033333  45.530000  6.600000   733.500000   92.000000  7.000000   63.000000   5.300000   13.275433  13.275433    1
# 2016-04-12 01:30:00  50          0       22.15  43.400000  20.000000  44.645000  23.426667  40.730000  22.200000  40.000000  21.000000  45.200000  7.656667   50.360000  21.700000  36.400000  22.890  45.236000  20.790000  43.433333  8.450000   751.650000   87.500000  3.000000   34.500000   6.450000   46.695186  46.695186    1
# ...

# %%
exam.nunique()
# Out:
# date           19735
# Appliances        92
# lights             8
# T1               722
# RH_1            2547
# T2              1650
# RH_2            3376
# T3              1426
# RH_3            2618
# T4              1390
# RH_4            2987
# T5              2263
# RH_5            7571
# T6              4446
# RH_6            9709
# T7              1955
# RH_7            5891
# T8              2228
# RH_8            6649
# T9               924
# RH_9            3388
# T_out           1730
# Press_mm_hg     2189
# RH_out           566
# Windspeed        189
# Visibility       413
# Tdewpoint       1409
# rv1            19735
# rv2            19735
# dtype: int64

# %%
exam.to_csv('regression-exam')
